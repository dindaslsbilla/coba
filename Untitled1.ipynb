# %%
import pandas as pd
import numpy as np

# %%
maingames = pd.read_csv('Maingames_DS_dataset.csv')
maingames
# Out:
#      Unnamed: 0 Country  Gender                       Game Total Follower  \
# 0             0      ID    Male                       MLBB          96751
# 1             1      ID    Male                8 Ball Pool           4781
# 2             2      ID  Female  Free Fire - Battlegrounds          68246
# 3             3      ID    Male                       MLBB         142037
# 4             4      ID    Male  Free Fire - Battlegrounds          15416
# ..          ...     ...     ...                        ...            ...
# 626         942      VN    Male                       PUBG         330969
# 627         943      VN    Male                  MU Online          33450
# 628         944      VN    Male             Age of Empires          29000
# 629         945      VN  Female                       PUBG          19771
# 630         946      VN    Male          League of Legends         515000
#
#      Broadcast Hours  PaidStarPerWatchedHour  Character_Facet_Cont_Rigidity  \
# ...

# %%
maingames_facefeature=maingames[["Character_Facet_Cont_Rigidity", "Character_Facet_Cont_AchievementStriving", "Personal_Values_Facet_Cont_Hedonism", "Character_Facet_Cont_Dutifulness", "Character_Cont_Conscientiousness", "Character_Facet_Cont_Sympathy", "Personal_Values_Facet_Cont_UniversalismTolerance", "Temperament_Choleric", "Self_Esteem_Cont_SEDiscrepancyResponsibility", "Character_Facet_Cont_ArtisticInterests", "Temperament_Sanguine", "Character_Facet_Cont_Friendliness", "Temperament_Diligent", "Self_Esteem_Cont_SELevel", "Character_Cont_Extraversion"]]

maingames_facefeature
# Out:
#      Character_Facet_Cont_Rigidity  Character_Facet_Cont_AchievementStriving  \
# 0                         0.663442                                  0.718679
# 1                         0.543255                                  0.427887
# 2                         0.527279                                  0.399873
# 3                         0.677222                                  0.603534
# 4                         0.238194                                  0.543285
# ..                             ...                                       ...
# 626                       0.534637                                  0.399738
# 627                       0.664025                                  0.597952
# 628                       0.561336                                  0.378814
# 629                       0.600844                                  0.364150
# 630                       0.664025                                  0.597952
#
# ...

# %%
rigidity=maingames_facefeature["Character_Facet_Cont_Rigidity"].mean()
achievement=maingames_facefeature["Character_Facet_Cont_AchievementStriving"].mean()
hedonism=maingames_facefeature["Personal_Values_Facet_Cont_Hedonism"].mean()
dutifulnes=maingames_facefeature["Character_Facet_Cont_Dutifulness"].mean()
print(rigidity,achievement,hedonism,dutifulnes)
# Out:
# 0.6022719289492868 0.511264169038035 0.5049681747987321 0.49582854291283673

# %%
maingames_facefeature.to_csv('maingames_facefeature.csv')

# %%
facefeature_df=pd.read_csv('maingames_facefeature.csv')
facefeature_df.mean(axis=0)
facefeature_df.drop(columns=facefeature_df.columns[0], 
        axis=1, 
        inplace=True)
facefeature_df.to_csv('maingames_facefeature.csv',index="False")
mean_row=facefeature_df.mean(axis=1)
facefeature_df['Mean']=mean_row
facefeature_df.to_csv('maingames_facefeature.csv',index="False")
facefeature_df
# Out:
#      Character_Facet_Cont_Rigidity  Character_Facet_Cont_AchievementStriving  \
# 0                         0.663442                                  0.718679
# 1                         0.543255                                  0.427887
# 2                         0.527279                                  0.399873
# 3                         0.677222                                  0.603534
# 4                         0.238194                                  0.543285
# ..                             ...                                       ...
# 626                       0.534637                                  0.399738
# 627                       0.664025                                  0.597952
# 628                       0.561336                                  0.378814
# 629                       0.600844                                  0.364150
# 630                       0.664025                                  0.597952
#
# ...

# %%
print(maingames.columns)
maingames_facefeature
# Out:
# Index(['Unnamed: 0', 'Country', 'Gender', 'Game', 'Total Follower',
#        'Broadcast Hours', 'PaidStarPerWatchedHour',
#        'Character_Facet_Cont_Rigidity',
#        'Character_Facet_Cont_AchievementStriving',
#        'Personal_Values_Facet_Cont_Hedonism',
#        ...
#        'Personal_Values_Facet_Cont_UniversalismNature', 'Role_Charismatic',
#        'Personal_Values_Facet_Cont_Tradition',
#        'Self_Esteem_Cont_SELevelAppearance',
#        'Character_Facet_Cont_Assertiveness',
#        'Character_Facet_Cont_Cautiousness', 'Role_Curator',
#        'Personal_Values_Cont_Conservation',
#        'Self_Esteem_Cont_SELevelIntelligence', 'Temperament_Centric'],
#       dtype='object', length=127)
#      Character_Facet_Cont_Rigidity  Character_Facet_Cont_AchievementStriving  \
# 0                         0.663442                                  0.718679
# 1                         0.543255                                  0.427887
# ...

# %%
maingames_roledirector = maingames[["Role_Director", "Character_Facet_Cont_SelfConsciousness", "Temperament_Energetic", "Character_Facet_Cont_Adventurousness"]]
maingames_roledirector
# Out:
#      Role_Director  Character_Facet_Cont_SelfConsciousness  \
# 0         0.679339                                0.471482
# 1         0.381432                                0.352964
# 2         0.305979                                0.750039
# 3         0.483526                                0.562344
# 4         0.359326                                0.449570
# ..             ...                                     ...
# 626       0.411055                                0.534298
# 627       0.552036                                0.424811
# 628       0.660348                                0.536923
# 629       0.457267                                0.527023
# 630       0.552036                                0.424811
#
#      Temperament_Energetic  Character_Facet_Cont_Adventurousness
# 0                    0.125                              0.544957
# 1                    0.000                              0.604113
# ...

# %%
maingames_roledirector.to_csv('maingames_roledirector.csv')

# %%
roledirector_df=pd.read_csv('maingames_roledirector.csv')
roledirector_df.mean(axis=0)
roledirector_df.drop(columns=roledirector_df.columns[0], 
        axis=1, 
        inplace=True)
roledirector_df.to_csv('maingames_roredirector.csv',index="False")
mean_row=roledirector_df.mean(axis=1)
roledirector_df['Mean']=mean_row
roledirector_df.to_csv('maingames_roledirector.csv',index="False")
roledirector_df
# Out:
#      Role_Director  Character_Facet_Cont_SelfConsciousness  \
# 0         0.679339                                0.471482
# 1         0.381432                                0.352964
# 2         0.305979                                0.750039
# 3         0.483526                                0.562344
# 4         0.359326                                0.449570
# ..             ...                                     ...
# 626       0.411055                                0.534298
# 627       0.552036                                0.424811
# 628       0.660348                                0.536923
# 629       0.457267                                0.527023
# 630       0.552036                                0.424811
#
#      Temperament_Energetic  Character_Facet_Cont_Adventurousness      Mean
# 0                    0.125                              0.544957  0.455194
# 1                    0.000                              0.604113  0.334627
# ...

# %%
maingames_rolecraftsman = maingames[["Role_Craftsman", "Self_Esteem_Cont_SELevelResponsibility", "Self_Esteem_Cont_SEAspirationResponsibility"]]
maingames_rolecraftsman
# Out:
#      Role_Craftsman  Self_Esteem_Cont_SELevelResponsibility  \
# 0          0.453882                                0.679427
# 1          0.325222                                0.743407
# 2          0.784232                                0.555626
# 3          0.187634                                0.674491
# 4          0.472548                                0.800546
# ..              ...                                     ...
# 626        0.732518                                0.690780
# 627        0.454408                                0.674840
# 628        0.646709                                0.612115
# 629        0.563095                                0.710236
# 630        0.454408                                0.674840
#
#      Self_Esteem_Cont_SEAspirationResponsibility
# 0                                       0.721495
# 1                                       0.534425
# 2                                       0.568014
# ...

# %%
maingames_rolecraftsman.to_csv('maingames_rolecraftsman.csv')

# %%
rolecraftsman_df=pd.read_csv('maingames_rolecraftsman.csv')
rolecraftsman_df.mean(axis=0)
rolecraftsman_df.drop(columns=rolecraftsman_df.columns[0], 
        axis=1, 
        inplace=True)
rolecraftsman_df.to_csv('maingames_rolecraftsman.csv',index="False")
mean_row=rolecraftsman_df.mean(axis=1)
rolecraftsman_df['Mean']=mean_row
rolecraftsman_df.to_csv('maingames_rolecraftsman.csv',index="False")
rolecraftsman_df
# Out:
#      Role_Craftsman  Self_Esteem_Cont_SELevelResponsibility  \
# 0          0.453882                                0.679427
# 1          0.325222                                0.743407
# 2          0.784232                                0.555626
# 3          0.187634                                0.674491
# 4          0.472548                                0.800546
# ..              ...                                     ...
# 626        0.732518                                0.690780
# 627        0.454408                                0.674840
# 628        0.646709                                0.612115
# 629        0.563095                                0.710236
# 630        0.454408                                0.674840
#
#      Self_Esteem_Cont_SEAspirationResponsibility      Mean
# 0                                       0.721495  0.618268
# 1                                       0.534425  0.534351
# 2                                       0.568014  0.635958
# ...

# %%
maingames_roletoastmaster = maingames[["Role_Toastmaster", "Personal_Values_Facet_Cont_PowerDominance"]]
maingames_roletoastmaster
# Out:
#      Role_Toastmaster  Personal_Values_Facet_Cont_PowerDominance
# 0            0.530887                                   0.356304
# 1            0.349459                                   0.341675
# 2            0.555618                                   0.362791
# 3            0.329684                                   0.350921
# 4            0.330917                                   0.325093
# ..                ...                                        ...
# 626          0.501546                                   0.347802
# 627          0.571264                                   0.341990
# 628          0.601269                                   0.357272
# 629          0.425726                                   0.351608
# 630          0.571264                                   0.341990
#
# [631 rows x 2 columns]

# %%
maingames_roletoastmaster.to_csv('maingames_roletoastmaster.csv')

# %%
roletoastmaster_df=pd.read_csv('maingames_roletoastmaster.csv')
roletoastmaster_df.mean(axis=0)
roletoastmaster_df.drop(columns=roletoastmaster_df.columns[0], 
        axis=1, 
        inplace=True)
roletoastmaster_df.to_csv('maingames_roletoastmaster.csv',index="False")
mean_row=roletoastmaster_df.mean(axis=1)
roletoastmaster_df['Mean']=mean_row
roletoastmaster_df.to_csv('maingames_roletoastmaster.csv',index="False")
roletoastmaster_df
# Out:
#      Role_Toastmaster  Personal_Values_Facet_Cont_PowerDominance      Mean
# 0            0.530887                                   0.356304  0.443595
# 1            0.349459                                   0.341675  0.345567
# 2            0.555618                                   0.362791  0.459204
# 3            0.329684                                   0.350921  0.340302
# 4            0.330917                                   0.325093  0.328005
# ..                ...                                        ...       ...
# 626          0.501546                                   0.347802  0.424674
# 627          0.571264                                   0.341990  0.456627
# 628          0.601269                                   0.357272  0.479271
# 629          0.425726                                   0.351608  0.388667
# 630          0.571264                                   0.341990  0.456627
#
# [631 rows x 3 columns]

# %%
maingames_rolemarshal = maingames[["Role_Marshal", "Self_Esteem_Cont_SELevelAchievements", "Self_Esteem_Cont_SEDiscrepancySociability", "Personal_Values_Cont_SelfEnhancement", "Self_Esteem_Cont_SEAspiration"]]
maingames_rolemarshal
# Out:
#      Role_Marshal  Self_Esteem_Cont_SELevelAchievements  \
# 0        0.620860                              0.605858
# 1        0.486200                              0.490160
# 2        0.177483                              0.189999
# 3        0.738135                              0.378579
# 4        0.203801                              0.628431
# ..            ...                                   ...
# 626      0.204186                              0.416851
# 627      0.669651                              0.459953
# 628      0.487343                              0.244142
# 629      0.408998                              0.380705
# 630      0.669651                              0.459953
#
#      Self_Esteem_Cont_SEDiscrepancySociability  \
# 0                                     0.473335
# 1                                     0.579283
# 2                                     0.510046
# 3                                     0.504088
# 4                                     0.423613
# ...

# %%
maingames_rolemarshal.to_csv('maingames_rolemarshal.csv')

# %%
rolemarshal_df=pd.read_csv('maingames_rolemarshal.csv')
rolemarshal_df.mean(axis=0)
rolemarshal_df.drop(columns=rolemarshal_df.columns[0], 
        axis=1, 
        inplace=True)
rolemarshal_df.to_csv('maingames_rolemarshal.csv',index="False")
mean_row=rolemarshal_df.mean(axis=1)
rolemarshal_df['Mean']=mean_row
rolemarshal_df.to_csv('maingames_rolemarshal.csv',index="False")
rolemarshal_df
# Out:
#      Role_Marshal  Self_Esteem_Cont_SELevelAchievements  \
# 0        0.620860                              0.605858
# 1        0.486200                              0.490160
# 2        0.177483                              0.189999
# 3        0.738135                              0.378579
# 4        0.203801                              0.628431
# ..            ...                                   ...
# 626      0.204186                              0.416851
# 627      0.669651                              0.459953
# 628      0.487343                              0.244142
# 629      0.408998                              0.380705
# 630      0.669651                              0.459953
#
#      Self_Esteem_Cont_SEDiscrepancySociability  \
# 0                                     0.473335
# 1                                     0.579283
# 2                                     0.510046
# 3                                     0.504088
# 4                                     0.423613
# ...

# %%
maingames_rolesupplier = maingames[["Role_Supplier", "Character_Facet_Cont_Activity", "Temperament_Stable", "Personal_Values_Facet_Cont_PowerResources",
"Self_Esteem_Cont_SEDiscrepancyAchievements", "Temperament_Melancholic", "Character_Cont_Openness", "Character_Facet_Cont_Anxiety"]]
maingames_rolesupplier
# Out:
#      Role_Supplier  Character_Facet_Cont_Activity  Temperament_Stable  \
# 0         0.509514                       0.691145               0.750
# 1         0.098237                       0.554197               0.625
# 2         0.360728                       0.546109               0.000
# 3         0.170067                       0.657482               0.500
# 4         0.376474                       0.401776               0.250
# ..             ...                            ...                 ...
# 626       0.267833                       0.405550               0.250
# 627       0.363288                       0.574830               0.125
# 628       0.518295                       0.550334               0.375
# 629       0.321306                       0.512605               0.250
# 630       0.363288                       0.574830               0.125
#
#      Personal_Values_Facet_Cont_PowerResources  \
# 0                                     0.317289
# ...

# %%
maingames_rolesupplier.to_csv('maingames_rolesupplier.csv')

# %%
rolesupplier_df=pd.read_csv('maingames_rolesupplier.csv')
rolesupplier_df.mean(axis=0)
rolesupplier_df.drop(columns=rolesupplier_df.columns[0], 
        axis=1, 
        inplace=True)
rolesupplier_df.to_csv('maingames_rolesupplier.csv',index="False")
mean_row=rolesupplier_df.mean(axis=1)
rolesupplier_df['Mean']=mean_row
rolesupplier_df.to_csv('maingames_rolesupplier.csv',index="False")
rolesupplier_df
# Out:
#      Role_Supplier  Character_Facet_Cont_Activity  Temperament_Stable  \
# 0         0.509514                       0.691145               0.750
# 1         0.098237                       0.554197               0.625
# 2         0.360728                       0.546109               0.000
# 3         0.170067                       0.657482               0.500
# 4         0.376474                       0.401776               0.250
# ..             ...                            ...                 ...
# 626       0.267833                       0.405550               0.250
# 627       0.363288                       0.574830               0.125
# 628       0.518295                       0.550334               0.375
# 629       0.321306                       0.512605               0.250
# 630       0.363288                       0.574830               0.125
#
#      Personal_Values_Facet_Cont_PowerResources  \
# 0                                     0.317289
# ...

# %%
maingames_roleadministrator = maingames[["Role_Administrator", "Character_Facet_Cont_Emotionality"]]
maingames_roleadministrator
# Out:
#      Role_Administrator  Character_Facet_Cont_Emotionality
# 0              0.572132                           0.663168
# 1              0.274649                           0.609838
# 2              0.488660                           0.753056
# 3              0.341728                           0.641477
# 4              0.348892                           0.501644
# ..                  ...                                ...
# 626            0.408857                           0.496105
# 627            0.564044                           0.556217
# 628            0.652206                           0.483922
# 629            0.446479                           0.462843
# 630            0.564044                           0.556217
#
# [631 rows x 2 columns]

# %%
maingames_roleadministrator.to_csv('maingames_roleadministrator.csv')

# %%
roleadministrator_df=pd.read_csv('maingames_roleadministrator.csv')
roleadministrator_df.mean(axis=0)
roleadministrator_df.drop(columns=roleadministrator_df.columns[0], 
        axis=1, 
        inplace=True)
roleadministrator_df.to_csv('maingames_roleadministrator.csv',index="False")
mean_row=roleadministrator_df.mean(axis=1)
roleadministrator_df['Mean']=mean_row
roleadministrator_df.to_csv('maingames_roleadministrator.csv',index="False")
roleadministrator_df
# Out:
#      Role_Administrator  Character_Facet_Cont_Emotionality      Mean
# 0              0.572132                           0.663168  0.617650
# 1              0.274649                           0.609838  0.442244
# 2              0.488660                           0.753056  0.620858
# 3              0.341728                           0.641477  0.491603
# 4              0.348892                           0.501644  0.425268
# ..                  ...                                ...       ...
# 626            0.408857                           0.496105  0.452481
# 627            0.564044                           0.556217  0.560130
# 628            0.652206                           0.483922  0.568064
# 629            0.446479                           0.462843  0.454661
# 630            0.564044                           0.556217  0.560130
#
# [631 rows x 3 columns]

# %%
maingames_roleinnovator = maingames[["Role_Innovator"]]
maingames_roleinnovator
# Out:
#      Role_Innovator
# 0          0.695563
# 1          0.675918
# 2          0.348778
# 3          0.684566
# 4          0.317387
# ..              ...
# 626        0.406728
# 627        0.770306
# 628        0.572594
# 629        0.501105
# 630        0.770306
#
# [631 rows x 1 columns]

# %%
maingames_roleinnovator.to_csv('maingames_roleinnovator.csv')

# %%
maingames_rolepartygoer = maingames[["Role_Partygoer", "Self_Esteem_Cont_SEAspirationSociability"]]
maingames_rolepartygoer
# Out:
#      Role_Partygoer  Self_Esteem_Cont_SEAspirationSociability
# 0          0.674684                                  0.720348
# 1          0.351584                                  0.606514
# 2          0.319777                                  0.840707
# 3          0.343166                                  0.745220
# 4          0.465105                                  0.892338
# ..              ...                                       ...
# 626        0.432631                                  0.842696
# 627        0.444076                                  0.694204
# 628        0.579259                                  0.882480
# 629        0.413125                                  0.893281
# 630        0.444076                                  0.694204
#
# [631 rows x 2 columns]

# %%
maingames_rolepartygoer.to_csv('maingames_rolepartygoer.csv')

# %%
rolepartygoer_df=pd.read_csv('maingames_rolepartygoer.csv')
rolepartygoer_df.mean(axis=0)
rolepartygoer_df.drop(columns=rolepartygoer_df.columns[0], 
        axis=1, 
        inplace=True)
rolepartygoer_df.to_csv('maingames_rolepartygoer.csv',index="False")
mean_row=rolepartygoer_df.mean(axis=1)
rolepartygoer_df['Mean']=mean_row
rolepartygoer_df.to_csv('maingames_rolepartygoer.csv',index="False")
rolepartygoer_df
# Out:
#      Role_Partygoer  Self_Esteem_Cont_SEAspirationSociability      Mean
# 0          0.674684                                  0.720348  0.697516
# 1          0.351584                                  0.606514  0.479049
# 2          0.319777                                  0.840707  0.580242
# 3          0.343166                                  0.745220  0.544193
# 4          0.465105                                  0.892338  0.678721
# ..              ...                                       ...       ...
# 626        0.432631                                  0.842696  0.637663
# 627        0.444076                                  0.694204  0.569140
# 628        0.579259                                  0.882480  0.730869
# 629        0.413125                                  0.893281  0.653203
# 630        0.444076                                  0.694204  0.569140
#
# [631 rows x 3 columns]

# %%
maingames_roleguru = maingames[["Role_Guru", "Personal_Values_Facet_Cont_SelfDirectionThought", "Temperament_Phlegmatic", "Personal_Values_Facet_Cont_Reputation"]]
maingames_roleguru
# Out:
#      Role_Guru  Personal_Values_Facet_Cont_SelfDirectionThought  \
# 0     0.758008                                         0.300860
# 1     0.382031                                         0.326278
# 2     0.341425                                         0.271818
# 3     0.379951                                         0.374888
# 4     0.632996                                         0.253147
# ..         ...                                              ...
# 626   0.371645                                         0.261911
# 627   0.485377                                         0.316931
# 628   0.649760                                         0.244408
# 629   0.640039                                         0.255363
# 630   0.485377                                         0.316931
#
#      Temperament_Phlegmatic  Personal_Values_Facet_Cont_Reputation
# 0                      0.25                               0.303197
# ...

# %%
maingames_roleguru.to_csv('maingames_roleguru.csv')

# %%
roleguru_df=pd.read_csv('maingames_roleguru.csv')
roleguru_df.mean(axis=0)
roleguru_df.drop(columns=roleguru_df.columns[0], 
        axis=1, 
        inplace=True)
roleguru_df.to_csv('maingames_roleguru.csv',index="False")
mean_row=roleguru_df.mean(axis=1)
roleguru_df['Mean']=mean_row
roleguru_df.to_csv('maingames_roleguru.csv',index="False")
roleguru_df
# Out:
#      Role_Guru  Personal_Values_Facet_Cont_SelfDirectionThought  \
# 0     0.758008                                         0.300860
# 1     0.382031                                         0.326278
# 2     0.341425                                         0.271818
# 3     0.379951                                         0.374888
# 4     0.632996                                         0.253147
# ..         ...                                              ...
# 626   0.371645                                         0.261911
# 627   0.485377                                         0.316931
# 628   0.649760                                         0.244408
# 629   0.640039                                         0.255363
# 630   0.485377                                         0.316931
#
#      Temperament_Phlegmatic  Personal_Values_Facet_Cont_Reputation      Mean
# 0                      0.25                               0.303197  0.403016
# ...

# %%
maingames_roleguardian = maingames[["Role_Guardian"]]
maingames_roleguardian
# Out:
#      Role_Guardian
# 0         0.560191
# 1         0.280925
# 2         0.644017
# 3         0.253581
# 4         0.523225
# ..             ...
# 626       0.564960
# 627       0.500243
# 628       0.772032
# 629       0.622296
# 630       0.500243
#
# [631 rows x 1 columns]

# %%
maingames_roleguardian.to_csv('maingames_roleguardian.csv')

# %%
maingames_rolekeeper = maingames[["Role_Keeper", "Character_Facet_Cont_Tension", "Character_Facet_Cont_Altruism", "Personal_Values_Facet_Cont_SecuritySocietal",
"Self_Esteem_Cont_SEAspirationAchievements", "Self_Esteem_Cont_SEAspirationOriginality", "Personal_Values_Facet_Cont_Humility", "Character_Facet_Cont_Orderliness"]]
maingames_rolekeeper
# Out:
#      Role_Keeper  Character_Facet_Cont_Tension  Character_Facet_Cont_Altruism  \
# 0       0.502705                      0.658563                       0.489029
# 1       0.105108                      0.572326                       0.310959
# 2       0.501414                      0.536447                       0.445137
# 3       0.084650                      0.610604                       0.331464
# 4       0.622450                      0.354810                       0.600798
# ..           ...                           ...                            ...
# 626     0.413601                      0.640935                       0.464019
# 627     0.308179                      0.598428                       0.312992
# 628     0.615253                      0.495842                       0.354062
# 629     0.488717                      0.603391                       0.231553
# 630     0.308179                      0.598428                       0.312992
#
# ...

# %%
maingames_rolekeeper.to_csv('maingames_rolekeeper.csv')

# %%
rolekeeper_df=pd.read_csv('maingames_rolekeeper.csv')
rolekeeper_df.mean(axis=0)
rolekeeper_df.drop(columns=rolekeeper_df.columns[0], 
        axis=1, 
        inplace=True)
rolekeeper_df.to_csv('maingames_rolekeeper.csv',index="False")
mean_row=rolekeeper_df.mean(axis=1)
rolekeeper_df['Mean']=mean_row
rolekeeper_df.to_csv('maingames_rolekeeper.csv',index="False")
rolekeeper_df
# Out:
#      Role_Keeper  Character_Facet_Cont_Tension  Character_Facet_Cont_Altruism  \
# 0       0.502705                      0.658563                       0.489029
# 1       0.105108                      0.572326                       0.310959
# 2       0.501414                      0.536447                       0.445137
# 3       0.084650                      0.610604                       0.331464
# 4       0.622450                      0.354810                       0.600798
# ..           ...                           ...                            ...
# 626     0.413601                      0.640935                       0.464019
# 627     0.308179                      0.598428                       0.312992
# 628     0.615253                      0.495842                       0.354062
# 629     0.488717                      0.603391                       0.231553
# 630     0.308179                      0.598428                       0.312992
#
# ...

# %%
maingames_rolemanager = maingames[["Role_Manager", "Personal_Values_Facet_Cont_Stimulation", "Character_Cont_Neuroticism", "Self_Esteem_Cont_SELevelConfidence", "Self_Esteem_Cont_SEAspirationConfidence"]]
maingames_rolemanager
# Out:
#      Role_Manager  Personal_Values_Facet_Cont_Stimulation  \
# 0        0.491607                                0.611376
# 1        0.147676                                0.534275
# 2        0.293106                                0.491731
# 3        0.257566                                0.463986
# 4        0.277707                                0.522099
# ..            ...                                     ...
# 626      0.119204                                0.464456
# 627      0.443186                                0.535072
# 628      0.414845                                0.436020
# 629      0.309137                                0.490297
# 630      0.443186                                0.535072
#
#      Character_Cont_Neuroticism  Self_Esteem_Cont_SELevelConfidence  \
# 0                      0.440367                            0.579454
# 1                      0.366972                            0.601624
# ...

# %%
maingames_rolemanager.to_csv('maingames_rolemanager.csv')

# %%
rolemanager_df=pd.read_csv('maingames_rolemanager.csv')
rolemanager_df.mean(axis=0)
rolemanager_df.drop(columns=rolemanager_df.columns[0], 
        axis=1, 
        inplace=True)
rolemanager_df.to_csv('maingames_rolemanager.csv',index="False")
mean_row=rolemanager_df.mean(axis=1)
rolemanager_df['Mean']=mean_row
rolemanager_df.to_csv('maingames_rolemanager.csv',index="False")
rolemanager_df
# Out:
#      Role_Manager  Personal_Values_Facet_Cont_Stimulation  \
# 0        0.491607                                0.611376
# 1        0.147676                                0.534275
# 2        0.293106                                0.491731
# 3        0.257566                                0.463986
# 4        0.277707                                0.522099
# ..            ...                                     ...
# 626      0.119204                                0.464456
# 627      0.443186                                0.535072
# 628      0.414845                                0.436020
# 629      0.309137                                0.490297
# 630      0.443186                                0.535072
#
#      Character_Cont_Neuroticism  Self_Esteem_Cont_SELevelConfidence  \
# 0                      0.440367                            0.579454
# 1                      0.366972                            0.601624
# ...

# %%
maingames_rolewiseman = maingames[["Role_WiseMan", "Self_Esteem_Cont_SEDiscrepancyConfidence"]]
maingames_rolewiseman
# Out:
#      Role_WiseMan  Self_Esteem_Cont_SEDiscrepancyConfidence
# 0        0.714230                                  0.757822
# 1        0.486980                                  0.539838
# 2        0.397467                                  0.601334
# 3        0.376739                                  0.484409
# 4        0.626009                                  0.498036
# ..            ...                                       ...
# 626      0.467731                                  0.476556
# 627      0.500222                                  0.467143
# 628      0.612332                                  0.525721
# 629      0.629167                                  0.503572
# 630      0.500222                                  0.467143
#
# [631 rows x 2 columns]

# %%
maingames_rolewiseman.to_csv('maingames_rolewiseman.csv')

# %%
rolewiseman_df=pd.read_csv('maingames_rolewiseman.csv')
rolewiseman_df.mean(axis=0)
rolewiseman_df.drop(columns=rolewiseman_df.columns[0], 
        axis=1, 
        inplace=True)
rolewiseman_df.to_csv('maingames_rolewiseman.csv',index="False")
mean_row=rolewiseman_df.mean(axis=1)
rolewiseman_df['Mean']=mean_row
rolewiseman_df.to_csv('maingames_rolewiseman.csv',index="False")
rolewiseman_df
# Out:
#      Role_WiseMan  Self_Esteem_Cont_SEDiscrepancyConfidence      Mean
# 0        0.714230                                  0.757822  0.736026
# 1        0.486980                                  0.539838  0.513409
# 2        0.397467                                  0.601334  0.499400
# 3        0.376739                                  0.484409  0.430574
# 4        0.626009                                  0.498036  0.562023
# ..            ...                                       ...       ...
# 626      0.467731                                  0.476556  0.472144
# 627      0.500222                                  0.467143  0.483683
# 628      0.612332                                  0.525721  0.569026
# 629      0.629167                                  0.503572  0.566370
# 630      0.500222                                  0.467143  0.483683
#
# [631 rows x 3 columns]

# %%
maingames_roleassistant = maingames[["Role_Assistant", "Self_Esteem_Cont_SEDiscrepancy", "Personal_Values_Facet_Cont_ConformityRules",
"Self_Esteem_Cont_SEAspirationIntelligence"]]
maingames_roleassistant
# Out:
#      Role_Assistant  Self_Esteem_Cont_SEDiscrepancy  \
# 0          0.426668                        0.363321
# 1          0.148169                        0.282683
# 2          0.578509                        0.624829
# 3          0.033375                        0.325990
# 4          0.593275                        0.434654
# ..              ...                             ...
# 626        0.521845                        0.628286
# 627        0.274210                        0.306794
# 628        0.528585                        0.632044
# 629        0.441517                        0.522990
# 630        0.274210                        0.306794
#
#      Personal_Values_Facet_Cont_ConformityRules  \
# 0                                      0.547592
# 1                                      0.476115
# 2                                      0.419879
# 3                                      0.570237
# 4                                      0.549794
# ...

# %%
maingames_roleassistant.to_csv('maingames_roleassistant.csv')

# %%
roleassistant_df=pd.read_csv('maingames_roleassistant.csv')
roleassistant_df.mean(axis=0)
roleassistant_df.drop(columns=roleassistant_df.columns[0], 
        axis=1, 
        inplace=True)
roleassistant_df.to_csv('maingames_roleassistant.csv',index="False")
mean_row=roleassistant_df.mean(axis=1)
roleassistant_df['Mean']=mean_row
roleassistant_df.to_csv('maingames_roleassistant.csv',index="False")
roleassistant_df
# Out:
#      Role_Assistant  Self_Esteem_Cont_SEDiscrepancy  \
# 0          0.426668                        0.363321
# 1          0.148169                        0.282683
# 2          0.578509                        0.624829
# 3          0.033375                        0.325990
# 4          0.593275                        0.434654
# ..              ...                             ...
# 626        0.521845                        0.628286
# 627        0.274210                        0.306794
# 628        0.528585                        0.632044
# 629        0.441517                        0.522990
# 630        0.274210                        0.306794
#
#      Personal_Values_Facet_Cont_ConformityRules  \
# 0                                      0.547592
# 1                                      0.476115
# 2                                      0.419879
# 3                                      0.570237
# 4                                      0.549794
# ...

# %%
maingames_rolehealer = maingames[["Role_Healer"]]
maingames_rolehealer
# Out:
#      Role_Healer
# 0       0.595266
# 1       0.356447
# 2       0.582897
# 3       0.267062
# 4       0.570800
# ..           ...
# 626     0.454974
# 627     0.510041
# 628     0.603615
# 629     0.588767
# 630     0.510041
#
# [631 rows x 1 columns]

# %%
maingames_rolehealer.to_csv('maingames_rolehealer.csv')

# %%
maingames_roleoperator = maingames[["Role_Operator", "Self_Esteem_Cont_SEDiscrepancyAppearance", "Personal_Values_Facet_Cont_ConformityInterpersonal",
"Character_Facet_Cont_Modesty", "Self_Esteem_Cont_SEDiscrepancyOriginality", "Character_Facet_Cont_Imagination"]]
maingames_roleoperator
# Out:
#      Role_Operator  Self_Esteem_Cont_SEDiscrepancyAppearance  \
# 0         0.608210                                  0.606057
# 1         0.518501                                  0.619994
# 2         0.476385                                  0.527887
# 3         0.353374                                  0.473965
# 4         0.549475                                  0.406912
# ..             ...                                       ...
# 626       0.814861                                  0.491154
# 627       0.479507                                  0.534129
# 628       0.714988                                  0.474618
# 629       0.643754                                  0.370962
# 630       0.479507                                  0.534129
#
#      Personal_Values_Facet_Cont_ConformityInterpersonal  \
# 0                                             0.545425
# 1                                             0.627668
# 2                                             0.620256
# ...

# %%
maingames_roleoperator.to_csv('maingames_roleoperator.csv')

# %%
roleoperator_df=pd.read_csv('maingames_roleoperator.csv')
roleoperator_df.mean(axis=0)
roleoperator_df.drop(columns=roleoperator_df.columns[0], 
        axis=1, 
        inplace=True)
roleoperator_df.to_csv('maingames_roleoperator.csv',index="False")
mean_row=roleoperator_df.mean(axis=1)
roleoperator_df['Mean']=mean_row
roleoperator_df.to_csv('maingames_roleoperator.csv',index="False")
roleoperator_df
# Out:
#      Role_Operator  Self_Esteem_Cont_SEDiscrepancyAppearance  \
# 0         0.608210                                  0.606057
# 1         0.518501                                  0.619994
# 2         0.476385                                  0.527887
# 3         0.353374                                  0.473965
# 4         0.549475                                  0.406912
# ..             ...                                       ...
# 626       0.814861                                  0.491154
# 627       0.479507                                  0.534129
# 628       0.714988                                  0.474618
# 629       0.643754                                  0.370962
# 630       0.479507                                  0.534129
#
#      Personal_Values_Facet_Cont_ConformityInterpersonal  \
# 0                                             0.545425
# 1                                             0.627668
# 2                                             0.620256
# ...

# %%
maingames_rolecoach = maingames[["Role_Coach"]]
maingames_rolecoach
# Out:
#      Role_Coach
# 0      0.492933
# 1      0.092588
# 2      0.171514
# 3      0.074850
# 4      0.646206
# ..          ...
# 626    0.333946
# 627    0.152213
# 628    0.503712
# 629    0.416377
# 630    0.152213
#
# [631 rows x 1 columns]

# %%
maingames_rolecoach.to_csv('maingames_rolecoach.csv')

# %%
maingames_rolerightsdefender = maingames[["Role_RightsDefender"]]
maingames_rolerightsdefender
# Out:
#      Role_RightsDefender
# 0               0.717802
# 1               0.464580
# 2               0.300321
# 3               0.474216
# 4               0.415214
# ..                   ...
# 626             0.335692
# 627             0.559642
# 628             0.533439
# 629             0.449200
# 630             0.559642
#
# [631 rows x 1 columns]

# %%
maingames_rolerightsdefender.to_csv('maingames_rolerightsdefender.csv')

# %%
maingames_rolephilanthropist = maingames[["Role_Philanthropist", "Personal_Values_Facet_Cont_SelfDirectionAction"]]
maingames_rolephilanthropist
# Out:
#      Role_Philanthropist  Personal_Values_Facet_Cont_SelfDirectionAction
# 0               0.690938                                        0.488144
# 1               0.320648                                        0.483454
# 2               0.172116                                        0.552369
# 3               0.458405                                        0.449760
# 4               0.359048                                        0.554442
# ..                   ...                                             ...
# 626             0.179938                                        0.621747
# 627             0.485556                                        0.447099
# 628             0.484469                                        0.582030
# 629             0.387595                                        0.597959
# 630             0.485556                                        0.447099
#
# [631 rows x 2 columns]

# %%
maingames_rolephilanthropist.to_csv('maingames_rolephilanthropist.csv')

# %%
rolephilanthropist_df=pd.read_csv('maingames_rolephilanthropist.csv')
rolephilanthropist_df.mean(axis=0)
rolephilanthropist_df.drop(columns=rolephilanthropist_df.columns[0], 
        axis=1, 
        inplace=True)
rolephilanthropist_df.to_csv('maingames_rolephilanthropist.csv',index="False")
mean_row=rolephilanthropist_df.mean(axis=1)
rolephilanthropist_df['Mean']=mean_row
rolephilanthropist_df.to_csv('maingames_rolephilanthropist.csv',index="False")
rolephilanthropist_df
# Out:
#      Role_Philanthropist  Personal_Values_Facet_Cont_SelfDirectionAction  \
# 0               0.690938                                        0.488144
# 1               0.320648                                        0.483454
# 2               0.172116                                        0.552369
# 3               0.458405                                        0.449760
# 4               0.359048                                        0.554442
# ..                   ...                                             ...
# 626             0.179938                                        0.621747
# 627             0.485556                                        0.447099
# 628             0.484469                                        0.582030
# 629             0.387595                                        0.597959
# 630             0.485556                                        0.447099
#
#          Mean
# 0    0.589541
# 1    0.402051
# 2    0.362242
# 3    0.454082
# ...

# %%
maingames_rolepromoter = maingames[["Role_Promoter", "Personal_Values_Facet_Cont_SecurityPersonal", "Personal_Values_Facet_Cont_UniversalismConcern"]]
maingames_rolepromoter
# Out:
#      Role_Promoter  Personal_Values_Facet_Cont_SecurityPersonal  \
# 0         0.674905                                     0.353928
# 1         0.503096                                     0.425649
# 2         0.390857                                     0.355100
# 3         0.485926                                     0.207889
# 4         0.385112                                     0.662919
# ..             ...                                          ...
# 626       0.538504                                     0.281641
# 627       0.593325                                     0.465490
# 628       0.651608                                     0.603522
# 629       0.479277                                     0.503608
# 630       0.593325                                     0.465490
#
#      Personal_Values_Facet_Cont_UniversalismConcern
# 0                                          0.477637
# 1                                          0.456436
# ...

# %%
maingames_rolepromoter.to_csv('maingames_rolepromoter.csv')

# %%
rolepromoter_df=pd.read_csv('maingames_rolepromoter.csv')
rolepromoter_df.mean(axis=0)
rolepromoter_df.drop(columns=rolepromoter_df.columns[0], 
        axis=1, 
        inplace=True)
rolepromoter_df.to_csv('maingames_rolepromoter.csv',index="False")
mean_row=rolepromoter_df.mean(axis=1)
rolepromoter_df['Mean']=mean_row
rolepromoter_df.to_csv('maingames_rolepromoter.csv',index="False")
rolepromoter_df
# Out:
#      Role_Promoter  Personal_Values_Facet_Cont_SecurityPersonal  \
# 0         0.674905                                     0.353928
# 1         0.503096                                     0.425649
# 2         0.390857                                     0.355100
# 3         0.485926                                     0.207889
# 4         0.385112                                     0.662919
# ..             ...                                          ...
# 626       0.538504                                     0.281641
# 627       0.593325                                     0.465490
# 628       0.651608                                     0.603522
# 629       0.479277                                     0.503608
# 630       0.593325                                     0.465490
#
#      Personal_Values_Facet_Cont_UniversalismConcern      Mean
# 0                                          0.477637  0.502157
# 1                                          0.456436  0.461727
# ...

# %%
maingames_roleadvisor = maingames[["Role_Advisor", "Self_Esteem_Cont_SELevelOriginality"]]
maingames_roleadvisor
# Out:
#      Role_Advisor  Self_Esteem_Cont_SELevelOriginality
# 0        0.577660                             0.728769
# 1        0.239550                             0.771001
# 2        0.490699                             0.546902
# 3        0.232493                             0.747797
# 4        0.558525                             0.618217
# ..            ...                                  ...
# 626      0.331455                             0.591234
# 627      0.457990                             0.729991
# 628      0.593427                             0.678415
# 629      0.569960                             0.609355
# 630      0.457990                             0.729991
#
# [631 rows x 2 columns]

# %%
maingames_roleadvisor.to_csv('maingames_roleadvisor.csv')

# %%
roleadvisor_df=pd.read_csv('maingames_roleadvisor.csv')
roleadvisor_df.mean(axis=0)
roleadvisor_df.drop(columns=roleadvisor_df.columns[0], 
        axis=1, 
        inplace=True)
roleadvisor_df.to_csv('maingames_roleadvisor.csv',index="False")
mean_row=roleadvisor_df.mean(axis=1)
roleadvisor_df['Mean']=mean_row
roleadvisor_df.to_csv('maingames_roleadvisor.csv',index="False")
roleadvisor_df
# Out:
#      Role_Advisor  Self_Esteem_Cont_SELevelOriginality      Mean
# 0        0.577660                             0.728769  0.653215
# 1        0.239550                             0.771001  0.505276
# 2        0.490699                             0.546902  0.518800
# 3        0.232493                             0.747797  0.490145
# 4        0.558525                             0.618217  0.588371
# ..            ...                                  ...       ...
# 626      0.331455                             0.591234  0.461344
# 627      0.457990                             0.729991  0.593991
# 628      0.593427                             0.678415  0.635921
# 629      0.569960                             0.609355  0.589657
# 630      0.457990                             0.729991  0.593991
#
# [631 rows x 3 columns]

# %%
maingames_roleanalyst = maingames[["Role_Analyst", "Personal_Values_Cont_SelfTranscendence", "Personal_Values_Facet_Cont_Achievement", "Character_Facet_Cont_Trust",
"Temperament_Unstable", "Character_Cont_Agreeableness"]]
maingames_roleanalyst
# Out:
#      Role_Analyst  Personal_Values_Cont_SelfTranscendence  \
# 0        0.627180                                0.275763
# 1        0.403616                                0.264248
# 2        0.610825                                0.244235
# 3        0.389318                                0.264291
# 4        0.486908                                0.286270
# ..            ...                                     ...
# 626      0.458982                                0.260506
# 627      0.658503                                0.238004
# 628      0.722407                                0.264304
# 629      0.697034                                0.266221
# 630      0.658503                                0.238004
#
#      Personal_Values_Facet_Cont_Achievement  Character_Facet_Cont_Trust  \
# 0                                  0.322608                    0.450080
# 1                                  0.333644                    0.504510
# ...

# %%
maingames_roleanalyst.to_csv('maingames_roleanalyst.csv')

# %%
roleanalyst_df=pd.read_csv('maingames_roleanalyst.csv')
roleanalyst_df.mean(axis=0)
roleanalyst_df.drop(columns=roleanalyst_df.columns[0], 
        axis=1, 
        inplace=True)
roleanalyst_df.to_csv('maingames_roleanalyst.csv',index="False")
mean_row=roleanalyst_df.mean(axis=1)
roleanalyst_df['Mean']=mean_row
roleanalyst_df.to_csv('maingames_roleanalyst.csv',index="False")
roleanalyst_df
# Out:
#      Role_Analyst  Personal_Values_Cont_SelfTranscendence  \
# 0        0.627180                                0.275763
# 1        0.403616                                0.264248
# 2        0.610825                                0.244235
# 3        0.389318                                0.264291
# 4        0.486908                                0.286270
# ..            ...                                     ...
# 626      0.458982                                0.260506
# 627      0.658503                                0.238004
# 628      0.722407                                0.264304
# 629      0.697034                                0.266221
# 630      0.658503                                0.238004
#
#      Personal_Values_Facet_Cont_Achievement  Character_Facet_Cont_Trust  \
# 0                                  0.322608                    0.450080
# 1                                  0.333644                    0.504510
# ...

# %%
maingames_roleinventor = maingames[["Role_Inventor", "Personal_Values_Facet_Cont_BenevolenceCaring", "Personal_Values_Facet_Cont_BenevolenceDependability",
"Character_Facet_Cont_Vulnerability", "Character_Facet_Cont_ExcitementSeeking"]]
maingames_roleinventor
# Out:
#      Role_Inventor  Personal_Values_Facet_Cont_BenevolenceCaring  \
# 0         0.705475                                      0.543155
# 1         0.718745                                      0.460678
# 2         0.476994                                      0.464157
# 3         0.536129                                      0.430808
# 4         0.509520                                      0.524065
# ..             ...                                           ...
# 626       0.585044                                      0.528665
# 627       0.678079                                      0.505461
# 628       0.686741                                      0.566174
# 629       0.749344                                      0.496616
# 630       0.678079                                      0.505461
#
#      Personal_Values_Facet_Cont_BenevolenceDependability  \
# 0                                             0.244511
# 1                                             0.276966
# ...

# %%
maingames_roleinventor.to_csv('maingames_roleinventor.csv')

# %%
roleinventor_df=pd.read_csv('maingames_roleinventor.csv')
roleinventor_df.mean(axis=0)
roleinventor_df.drop(columns=roleinventor_df.columns[0], 
        axis=1, 
        inplace=True)
roleinventor_df.to_csv('maingames_roleinventor.csv',index="False")
mean_row=roleinventor_df.mean(axis=1)
roleinventor_df['Mean']=mean_row
roleinventor_df.to_csv('maingames_roleinventor.csv',index="False")
roleinventor_df
# Out:
#      Role_Inventor  Personal_Values_Facet_Cont_BenevolenceCaring  \
# 0         0.705475                                      0.543155
# 1         0.718745                                      0.460678
# 2         0.476994                                      0.464157
# 3         0.536129                                      0.430808
# 4         0.509520                                      0.524065
# ..             ...                                           ...
# 626       0.585044                                      0.528665
# 627       0.678079                                      0.505461
# 628       0.686741                                      0.566174
# 629       0.749344                                      0.496616
# 630       0.678079                                      0.505461
#
#      Personal_Values_Facet_Cont_BenevolenceDependability  \
# 0                                             0.244511
# 1                                             0.276966
# ...

# %%
maingames_roledesigner = maingames[["Role_Designer"]]
maingames_roledesigner
# Out:
#      Role_Designer
# 0         0.533952
# 1         0.488030
# 2         0.715200
# 3         0.353331
# 4         0.439376
# ..             ...
# 626       0.539938
# 627       0.648300
# 628       0.620921
# 629       0.657633
# 630       0.648300
#
# [631 rows x 1 columns]

# %%
maingames_roledesigner.to_csv('maingames_roledesigner.csv')

# %%
maingames_roledeputy = maingames[["Role_Deputy", "Personal_Values_Cont_OpennessToChange", "Character_Facet_Cont_Morality",
"Character_Facet_Cont_Depression"]]
maingames_roledeputy
# Out:
#      Role_Deputy  Personal_Values_Cont_OpennessToChange  \
# 0       0.516859                               0.303909
# 1       0.263292                               0.309062
# 2       0.302466                               0.295549
# 3       0.126136                               0.299255
# 4       0.671446                               0.294530
# ..           ...                                    ...
# 626     0.541257                               0.300088
# 627     0.231728                               0.302622
# 628     0.519184                               0.279882
# 629     0.457612                               0.300414
# 630     0.231728                               0.302622
#
#      Character_Facet_Cont_Morality  Character_Facet_Cont_Depression
# 0                         0.553544                         0.771031
# 1                         0.352700                         0.462166
# 2                         0.657773                         0.753035
# ...

# %%
maingames_roledeputy.to_csv('maingames_roledeputy.csv')

# %%
roledeputy_df=pd.read_csv('maingames_roledeputy.csv')
roledeputy_df.mean(axis=0)
roledeputy_df.drop(columns=roledeputy_df.columns[0], 
        axis=1, 
        inplace=True)
roledeputy_df.to_csv('maingames_roledeputy.csv',index="False")
mean_row=roledeputy_df.mean(axis=1)
roledeputy_df['Mean']=mean_row
roledeputy_df.to_csv('maingames_roledeputy.csv',index="False")
roledeputy_df
# Out:
#      Role_Deputy  Personal_Values_Cont_OpennessToChange  \
# 0       0.516859                               0.303909
# 1       0.263292                               0.309062
# 2       0.302466                               0.295549
# 3       0.126136                               0.299255
# 4       0.671446                               0.294530
# ..           ...                                    ...
# 626     0.541257                               0.300088
# 627     0.231728                               0.302622
# 628     0.519184                               0.279882
# 629     0.457612                               0.300414
# 630     0.231728                               0.302622
#
#      Character_Facet_Cont_Morality  Character_Facet_Cont_Depression      Mean
# 0                         0.553544                         0.771031  0.536336
# 1                         0.352700                         0.462166  0.346805
# ...

# %%
maingames_rolestrategist = maingames[["Role_Strategist"]]
maingames_rolestrategist
# Out:
#      Role_Strategist
# 0           0.783868
# 1           0.549318
# 2           0.437836
# 3           0.538656
# 4           0.535046
# ..               ...
# 626         0.484337
# 627         0.672555
# 628         0.770253
# 629         0.771808
# 630         0.672555
#
# [631 rows x 1 columns]

# %%
maingames_rolestrategist.to_csv('maingames_rolestrategist.csv')

# %%
maingames_roleinspector = maingames[["Role_Inspector", "Self_Esteem_Cont_SEAspirationAppearance", "Character_Facet_Cont_SelfDiscipline",
"Self_Esteem_Cont_SEDiscrepancyIntelligence"]]
maingames_roleinspector
# Out:
#      Role_Inspector  Self_Esteem_Cont_SEAspirationAppearance  \
# 0          0.670467                                 0.648751
# 1          0.397981                                 0.690168
# 2          0.416392                                 0.850414
# 3          0.370693                                 0.629667
# 4          0.568810                                 0.861587
# ..              ...                                      ...
# 626        0.593582                                 0.812672
# 627        0.482941                                 0.674911
# 628        0.808813                                 0.887988
# 629        0.671684                                 0.844177
# 630        0.482941                                 0.674911
#
#      Character_Facet_Cont_SelfDiscipline  \
# 0                               0.518061
# 1                               0.442303
# 2                               0.385781
# 3                               0.535313
# ...

# %%
maingames_roleinspector.to_csv('maingames_roleinspector.csv')

# %%
roleinspector_df=pd.read_csv('maingames_roleinspector.csv')
roleinspector_df.mean(axis=0)
roleinspector_df.drop(columns=roleinspector_df.columns[0], 
        axis=1, 
        inplace=True)
roleinspector_df.to_csv('maingames_roleinspector.csv',index="False")
mean_row=roleinspector_df.mean(axis=1)
roleinspector_df['Mean']=mean_row
roleinspector_df.to_csv('maingames_roleinspector.csv',index="False")
roleinspector_df
# Out:
#      Role_Inspector  Self_Esteem_Cont_SEAspirationAppearance  \
# 0          0.670467                                 0.648751
# 1          0.397981                                 0.690168
# 2          0.416392                                 0.850414
# 3          0.370693                                 0.629667
# 4          0.568810                                 0.861587
# ..              ...                                      ...
# 626        0.593582                                 0.812672
# 627        0.482941                                 0.674911
# 628        0.808813                                 0.887988
# 629        0.671684                                 0.844177
# 630        0.482941                                 0.674911
#
#      Character_Facet_Cont_SelfDiscipline  \
# 0                               0.518061
# 1                               0.442303
# 2                               0.385781
# 3                               0.535313
# ...

# %%
maingames_rolecompanion = maingames[["Role_Companion", "Character_Facet_Cont_Cooperation"]]
maingames_rolecompanion
# Out:
#      Role_Companion  Character_Facet_Cont_Cooperation
# 0          0.541372                          0.352032
# 1          0.230455                          0.401419
# 2          0.463357                          0.335437
# 3          0.218070                          0.461569
# 4          0.415672                          0.437006
# ..              ...                               ...
# 626        0.404199                          0.356727
# 627        0.430298                          0.443001
# 628        0.543926                          0.328976
# 629        0.372419                          0.293304
# 630        0.430298                          0.443001
#
# [631 rows x 2 columns]

# %%
maingames_rolecompanion.to_csv('maingames_rolecompanion.csv')

# %%
rolecompanion_df=pd.read_csv('maingames_rolecompanion.csv')
rolecompanion_df.mean(axis=0)
rolecompanion_df.drop(columns=rolecompanion_df.columns[0], 
        axis=1, 
        inplace=True)
rolecompanion_df.to_csv('maingames_rolecompanion.csv',index="False")
mean_row=rolecompanion_df.mean(axis=1)
rolecompanion_df['Mean']=mean_row
rolecompanion_df.to_csv('maingames_rolecompanion.csv',index="False")
rolecompanion_df
# Out:
#      Role_Companion  Character_Facet_Cont_Cooperation      Mean
# 0          0.541372                          0.352032  0.446702
# 1          0.230455                          0.401419  0.315937
# 2          0.463357                          0.335437  0.399397
# 3          0.218070                          0.461569  0.339819
# 4          0.415672                          0.437006  0.426339
# ..              ...                               ...       ...
# 626        0.404199                          0.356727  0.380463
# 627        0.430298                          0.443001  0.436649
# 628        0.543926                          0.328976  0.436451
# 629        0.372419                          0.293304  0.332862
# 630        0.430298                          0.443001  0.436649
#
# [631 rows x 3 columns]

# %%
maingames_rolecommander = maingames[["Role_Commander"]]
maingames_rolecommander
# Out:
#      Role_Commander
# 0          0.449807
# 1          0.277163
# 2          0.361047
# 3          0.419304
# 4          0.150856
# ..              ...
# 626        0.171780
# 627        0.643068
# 628        0.444178
# 629        0.350901
# 630        0.643068
#
# [631 rows x 1 columns]

# %%
maingames_rolecommander.to_csv('maingames_rolecommander.csv')

# %%
maingames_roleactivist = maingames[["Role_Activist", "Personal_Values_Facet_Cont_UniversalismNature"]]
maingames_roleactivist
# Out:
#      Role_Activist  Personal_Values_Facet_Cont_UniversalismNature
# 0         0.514417                                       0.523116
# 1         0.286003                                       0.444493
# 2         0.401512                                       0.581657
# 3         0.290019                                       0.385822
# 4         0.319439                                       0.582025
# ..             ...                                            ...
# 626       0.258000                                       0.568354
# 627       0.503077                                       0.409843
# 628       0.439392                                       0.594737
# 629       0.352059                                       0.473707
# 630       0.503077                                       0.409843
#
# [631 rows x 2 columns]

# %%
maingames_roleactivist.to_csv('maingames_roleactivist.csv')

# %%
roleactivist_df=pd.read_csv('maingames_roleactivist.csv')
roleactivist_df.mean(axis=0)
roleactivist_df.drop(columns=roleactivist_df.columns[0], 
        axis=1, 
        inplace=True)
roleactivist_df.to_csv('maingames_roleactivist.csv',index="False")
mean_row=roleactivist_df.mean(axis=1)
roleactivist_df['Mean']=mean_row
roleactivist_df.to_csv('maingames_roleactivist',index="False")
roleactivist_df
# Out:
#      Role_Activist  Personal_Values_Facet_Cont_UniversalismNature      Mean
# 0         0.514417                                       0.523116  0.518767
# 1         0.286003                                       0.444493  0.365248
# 2         0.401512                                       0.581657  0.491585
# 3         0.290019                                       0.385822  0.337920
# 4         0.319439                                       0.582025  0.450732
# ..             ...                                            ...       ...
# 626       0.258000                                       0.568354  0.413177
# 627       0.503077                                       0.409843  0.456460
# 628       0.439392                                       0.594737  0.517065
# 629       0.352059                                       0.473707  0.412883
# 630       0.503077                                       0.409843  0.456460
#
# [631 rows x 3 columns]
